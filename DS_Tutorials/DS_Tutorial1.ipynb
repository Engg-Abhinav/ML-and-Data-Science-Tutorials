# %% [markdown]
# <a href="https://colab.research.google.com/github/Engg-Abhinav/DS-Projects/blob/main/DS_Tutorials/DS_Tutorial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Outliers
# Z-Score

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Defining Dataset
dataset = [11,10,12,14,12,15,14,13,15,102,12,14,17,19,107,10,13,12,14,13,15,10,15,12,10,14,13,15,102]

# %%
plt.hist(dataset)
# Out:
# (array([27.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  2.]),
#  array([ 10. ,  19.7,  29.4,  39.1,  48.8,  58.5,  68.2,  77.9,  87.6,
#          97.3, 107. ]),
#  <BarContainer object of 10 artists>)

# %%
outliers = []

def detect_outliers(data):
  threshold = 3 # 3rd deviation
  mean = np.mean(data)
  std = np.std(data)

  for i in data:
    z_score = (i-mean)/std
    if np.abs(z_score) > threshold:
      outliers.append(i)

  return outliers

# %%
detect_outliers(dataset)
# Out:
# [102, 107]

# %% [markdown]
# # IQR - Inter Quartile Range
# 1. Sort the Data
# 2. Calculate Q1 and Q3
# 3. IQR = Q3 - Q1
# 4. Find the Lower fence(q1-1.5(IQR))
# 5. Find the Upper fence(q3+1.5(IQR))

# %%
dataset = sorted(dataset)
dataset
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  17,
#  19,
#  102,
#  107]

# %%
q1, q3 = np.percentile(dataset, [25, 75])

# %%
print(q1, q3)
# Out:
# 12.0 15.0

# %%
iqr = q3 - q1
print(iqr)
# Out:
# 3.0

# %%
# Finding th lower and higher fence
lower_fence = q1 - (1.5*iqr)
higher_fence = q3 + (1.5*iqr)

# %%
print(lower_fence, higher_fence)
# Out:
# 7.5 19.5

# %%
import seaborn as sns

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >
